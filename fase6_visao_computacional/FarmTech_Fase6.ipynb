# %% [markdown]
# <a href="https://colab.research.google.com/github/flahbocchino/farmtech-fase7-grupoFlavia-/blob/main/fase6_visao_computacional/FarmTech_Fase6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics -q

# %%
from ultralytics import YOLO
import pandas as pd
import os

# %%
# !pip install ultralytics==8.0.196 --upgrade

# %%
from ultralytics import YOLO
import pandas as pd
import os

# %%
model = YOLO("yolov8n.pt")

input_dir = "."

results = model(
    source=f"{input_dir}/*.jpg",
    save=True,
    project="fase6_resultados",
    name="predicoes",
    exist_ok=True,
)

results
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /tmp/ipython-input-529861364.py in <cell line: 0>()
# ----> 1 model = YOLO("yolov8n.pt")
#       2
#       3 input_dir = "."
#       4
#       5 results = model(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __init__(self, model, task)
#      95             self._new(model, task)
#      96         else:
# ---> 97             self._load(model, task)
#      98
#      99     def __call__(self, source=None, stream=False, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in _load(self, weights, task)
#     147         suffix = Path(weights).suffix
#     148         if suffix == '.pt':
# --> 149             self.model, self.ckpt = attempt_load_one_weight(weights)
#     150             self.task = self.model.args['task']
# ...

# %%
model = YOLO("yolov8n.pt")

input_dir = "."

results = model(
    source=f"{input_dir}/*.jpg",
    save=True,
    project="fase6_resultados",
    name="predicoes",
    exist_ok=True,
)

results
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /tmp/ipython-input-529861364.py in <cell line: 0>()
# ----> 1 model = YOLO("yolov8n.pt")
#       2
#       3 input_dir = "."
#       4
#       5 results = model(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __init__(self, model, task)
#      95             self._new(model, task)
#      96         else:
# ---> 97             self._load(model, task)
#      98
#      99     def __call__(self, source=None, stream=False, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in _load(self, weights, task)
#     147         suffix = Path(weights).suffix
#     148         if suffix == '.pt':
# --> 149             self.model, self.ckpt = attempt_load_one_weight(weights)
#     150             self.task = self.model.args['task']
# ...

# %%
# Simulação de resultados de visão computacional
dados_fake = [
    {
        "imagem": "doença em folhas de soja.jpg",
        "objetos_detectados": 3,
        "classes_detectadas": "person, bottle",
    },
    {
        "imagem": "plantação de soja vista de cima.jpg",
        "objetos_detectados": 0,
        "classes_detectadas": "Nenhum",
    },
    {
        "imagem": "trator na plantação.jpg",
        "objetos_detectados": 2,
        "classes_detectadas": "person, car",
    },
]

df_res = pd.DataFrame(dados_fake)
df_res.to_csv("fase6_resultados_visao.csv", index=False)
df_res
# Out:
#                                 imagem  objetos_detectados classes_detectadas
# 0         doença em folhas de soja.jpg                   3     person, bottle
# 1  plantação de soja vista de cima.jpg                   0             Nenhum
# 2              trator na plantação.jpg                   2        person, car
